# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# This is a Test to indicate that the payload is imported
# Note: NotebookUtils is only supported on runtime v1.2 and above. If you are using runtime v1.1, please use mssparkutils instead.
if not len(notebookutils.fs.mounts({"scope": "default_lh"})) > 0:
    raise Exception("No found default Lakehouse mount point")
# Out:
# StatementMeta(, 12dcd1ba-f3f2-4dee-af51-02a97b5a51e0, 3, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Note: NotebookUtils is only supported on runtime v1.2 and above. If you are using runtime v1.1, please use mssparkutils instead.
#       2 if not len(notebookutils.fs.mounts({"scope": "default_lh"})) > 0:
# ----> 3     raise Exception("No found default Lakehouse mount point")
#
# Exception: No found default Lakehouse mount point
